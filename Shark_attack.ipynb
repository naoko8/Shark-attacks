# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("attacks.csv")

# %%
data
# Out:
#       Case Number       Date    Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1      2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2      2018.06.09   9-Jun-18  2018.0     Invalid        USA           Hawaii
# 3      2018.06.08   8-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04   4-Jun-18  2018.0    Provoked     MEXICO           Colima
# ...           ...        ...     ...         ...        ...              ...
# 25718         NaN        NaN     NaN         NaN        NaN              NaN
# 25719         NaN        NaN     NaN         NaN        NaN              NaN
# 25720         NaN        NaN     NaN         NaN        NaN              NaN
# 25721         NaN        NaN     NaN         NaN        NaN              NaN
# 25722          xx        NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
data.isnull().all(axis=1).any()
# Out:
# True

# %%
data[data.isnull().all(axis=1)]
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8703          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8704          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8705          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8706          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...           ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# ...

# %%
data = data.dropna(axis=0, how="all")

# %%
data
# Out:
#       Case Number       Date    Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1      2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2      2018.06.09   9-Jun-18  2018.0     Invalid        USA           Hawaii
# 3      2018.06.08   8-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04   4-Jun-18  2018.0    Provoked     MEXICO           Colima
# ...           ...        ...     ...         ...        ...              ...
# 8698            0        NaN     NaN         NaN        NaN              NaN
# 8699            0        NaN     NaN         NaN        NaN              NaN
# 8700            0        NaN     NaN         NaN        NaN              NaN
# 8701            0        NaN     NaN         NaN        NaN              NaN
# 25722          xx        NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
data.isnull().all(axis=1).any()
# Out:
# False

# %%
data["Case Number"] = data["Case Number"].replace(to_replace="xx", value = 0)
# Out:
# <ipython-input-10-db38fb86490e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Case Number"] = data["Case Number"].replace(to_replace="xx", value = 0)

# %%
data
# Out:
#       Case Number       Date    Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1      2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2      2018.06.09   9-Jun-18  2018.0     Invalid        USA           Hawaii
# 3      2018.06.08   8-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04   4-Jun-18  2018.0    Provoked     MEXICO           Colima
# ...           ...        ...     ...         ...        ...              ...
# 8698            0        NaN     NaN         NaN        NaN              NaN
# 8699            0        NaN     NaN         NaN        NaN              NaN
# 8700            0        NaN     NaN         NaN        NaN              NaN
# 8701            0        NaN     NaN         NaN        NaN              NaN
# 25722           0        NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
data[data["Case Number"]=="0"]
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6302           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6303           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6304           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6305           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...          ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 8697           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8698           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... Species  Investigator or Source  pdf href formula href  \
# ...

# %%
data[(data["Case Number"] == 0) & (data["original order"].notnull())]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
data.iloc[8697]
# Out:
# Case Number                 0
# Date                      NaN
# Year                      NaN
# Type                      NaN
# Country                   NaN
# Area                      NaN
# Location                  NaN
# Activity                  NaN
# Name                      NaN
# Sex                       NaN
# Age                       NaN
# Injury                    NaN
# Fatal (Y/N)               NaN
# Time                      NaN
# Species                   NaN
# Investigator or Source    NaN
# pdf                       NaN
# href formula              NaN
# href                      NaN
# Case Number.1             NaN
# Case Number.2             NaN
# original order            NaN
# Unnamed: 22               NaN
# Unnamed: 23               NaN
# Name: 8697, dtype: object

# %%
data.iloc[6308:7000]
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6308           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6310           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6311           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6312           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...          ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 6995           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6996           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6997           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6998           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6999           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... Species  Investigator or Source  pdf href formula href  \
# ...

# %%
data[data["original order"].notnull()]
# Out:
#      Case Number       Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09   9-Jun-18  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08   8-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04   4-Jun-18  2018.0    Provoked     MEXICO           Colima
# ...          ...        ...     ...         ...        ...              ...
# 6304           0        NaN     NaN         NaN        NaN              NaN
# 6305           0        NaN     NaN         NaN        NaN              NaN
# 6306           0        NaN     NaN         NaN        NaN              NaN
# 6307           0        NaN     NaN         NaN        NaN              NaN
# 6308           0        NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
data = data.iloc[:-2394]

# %%
data.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
data
# We dont need this columns: Investigator or source, pdf, href formula, href, Case Number.1, Case Number.2, 
# Unnamed: 22, Unnamed: 23
# Out:
#      Case Number       Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09   9-Jun-18  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08   8-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04   4-Jun-18  2018.0    Provoked     MEXICO           Colima
# ...          ...        ...     ...         ...        ...              ...
# 6304           0        NaN     NaN         NaN        NaN              NaN
# 6305           0        NaN     NaN         NaN        NaN              NaN
# 6306           0        NaN     NaN         NaN        NaN              NaN
# 6307           0        NaN     NaN         NaN        NaN              NaN
# 6308           0        NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
columns_delete = ["Investigator or Source", "pdf", "href formula", "href", "Case Number.1", "Case Number.2", "Unnamed: 22", "Unnamed: 23"]

# %%
data = data.drop(columns_delete, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-fa4c9eb1cbd6> in <module>
# ----> 1 data = data.drop(columns_delete, axis=1)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
data
# Out:
#      Case Number       Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09   9-Jun-18  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08   8-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04   4-Jun-18  2018.0    Provoked     MEXICO           Colima
# ...          ...        ...     ...         ...        ...              ...
# 6304           0        NaN     NaN         NaN        NaN              NaN
# 6305           0        NaN     NaN         NaN        NaN              NaN
# 6306           0        NaN     NaN         NaN        NaN              NaN
# 6307           0        NaN     NaN         NaN        NaN              NaN
# 6308           0        NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
us = data[(data["Country"]=="USA") & (data["Fatal (Y/N)"]=="Y")]

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
us
# Out:
#      Case Number                  Date    Year        Type Country  \
# 429   2015.04.29             29-Apr-15  2015.0  Unprovoked     USA
# 596   2013.12.02              2-Dec-13  2013.0  Unprovoked     USA
# 639   2013.08.14           14-Aug-2013  2013.0  Unprovoked     USA
# 728   2012.10.23             23-Oct-12  2012.0  Unprovoked     USA
# 978   2010.10.22             22-Oct-10  2010.0  Unprovoked     USA
# ...          ...                   ...     ...         ...     ...
# 6151  1751.07.27           27-Jul-1751  1751.0  Unprovoked     USA
# 6168  1642.00.00                  1642  1642.0  Unprovoked     USA
# 6194     ND-0133           Before 1908     0.0  Unprovoked     USA
# 6233     ND.0078  No date, Before 1902     0.0  Unprovoked     USA
# 6299     ND.0003             1900-1905     0.0  Unprovoked     USA
#
#                 Area                                          Location  \
# 429           Hawaii                                    Kanahena Cove
# ...

# %%
us["Age"] = pd.to_numeric(us["Age"], errors='coerce')
# Out:
# <ipython-input-52-4814c360d16a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us["Age"] = pd.to_numeric(us["Age"], errors='coerce')

# %%
us["Sex "] # Maybe I should rename "Sex " to "Sex"
# Out:
# 429     F
# 596     M
# 639     F
# 728     M
# 978     M
#        ..
# 6151    M
# 6168    M
# 6194    M
# 6233    M
# 6299    M
# Name: Sex , Length: 186, dtype: object

# %%
plt.figure(figsize=(8, 12))

sns.barplot(data=us, x="Sex ", y= "Age");

# %% [markdown]
# #### why womens?

# %%
us.Activity.describe()
# Out:
# count          181
# unique          97
# top       Swimming
# freq            48
# Name: Activity, dtype: object

# %%
# us["Activity"].value_counts()[:5].index.tolist()

us["Activity"].value_counts()[:5]
# Out:
# Swimming          48
# Surfing            8
# Fishing            8
# Bathing            6
# Fell overboard     5
# Name: Activity, dtype: int64

# %%
list_of_activity = us["Activity"].value_counts()[:5].index.tolist()
list_of_activity
# Out:
# ['Swimming', 'Surfing', 'Fishing', 'Bathing', 'Fell overboard']

# %%
us["Activity"].value_counts().sum()
# Out:
# 181

# %%
size_of_activity = us["Activity"].value_counts()[:5].values

# %%
labels = list_of_activity
sizes = size_of_activity 

explode = (0.1, 0, 0, 0, 0) #გამოყოფა


plt.figure(figsize=(15, 7)) #ზომა

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%'); #float-ის ერთი ნულის დატოვება

# %% [markdown]
# #### Lets now see global view of data.

# %%
### Why women are much more then men.

# %%
globally = data[data["Fatal (Y/N)"]=="Y"]

# %%
globally
# Out:
#        Case Number                  Date    Year          Type  \
# 6     2018.06.03.a              3-Jun-18  2018.0    Unprovoked
# 58    2017.11.30.a             30-Nov-17  2017.0    Unprovoked
# 59    2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster
# 64      2017.11.04              4-Nov-17  2017.0    Unprovoked
# 91    2017.09.03.b              3-Sep-17  2017.0    Unprovoked
# ...            ...                   ...     ...           ...
# 6297       ND.0005           Before 1903     0.0    Unprovoked
# 6298       ND.0004           Before 1903     0.0    Unprovoked
# 6299       ND.0003             1900-1905     0.0    Unprovoked
# 6300       ND.0002             1883-1889     0.0    Unprovoked
# 6301       ND.0001             1845-1853     0.0    Unprovoked
#
#                  Country                   Area  \
# 6                 BRAZIL             Pernambuco
# 58            COSTA RICA           Cocos Island
# 59                 LIBYA                    NaN
# ...

# %%
globally["Age"] = pd.to_numeric(globally["Age"], errors='coerce')
# Out:
# <ipython-input-126-683e13261a6d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globally["Age"] = pd.to_numeric(globally["Age"], errors='coerce')

# %%
# Out:
# 6       18.0
# 58      49.0
# 59       NaN
# 64      22.0
# 91       NaN
#         ...
# 6297     NaN
# 6298     NaN
# 6299     NaN
# 6300     NaN
# 6301    15.0
# Name: Age, Length: 1388, dtype: float64

# %%
plt.figure(figsize=(8, 10))

sns.barplot(data=globally, x="Sex ", y= "Age");

# %%
# so strange whyyyyyyyy

# %%
list_of_global_activities = globally["Activity"].value_counts()[:5].index.tolist()

# %%
size_of_global_activities = globally["Activity"].value_counts()[:5].values

# %%
# Out:
# array([304,  70,  49,  47,  41], dtype=int64)

# %%
labels = list_of_global_activities
sizes = size_of_global_activities 

explode = (0.1, 0, 0, 0, 0) #გამოყოფა

colors = ['#FFADBD','#E9DF6C','#D3EA95','#AEEA95', "#D9EFEB"]

plt.figure(figsize=(15, 7)) #ზომა

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', colors = colors); #float-ის ერთი ნულის დატოვება
